# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import opendatasets as od

# %% [markdown]
# **download and load the datasets**

# %%
od.download(
    "https://www.kaggle.com/datasets/greegtitan/indonesia-climate?select=climate_data.csv")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: putriafianurfallahi
# Your Kaggle Key: ··········
# Downloading indonesia-climate.zip to ./indonesia-climate
# 100%|██████████| 7.15M/7.15M [00:00<00:00, 54.5MB/s]

# %%
df = pd.read_csv('/content/indonesia-climate/climate_data.csv')
df.head()
# Out:
#          date    Tn    Tx  Tavg  RH_avg    RR   ss  ff_x  ddd_x  ff_avg  \
# 0  01-01-2010  21.4  30.2  27.1    82.0   9.0  0.5   7.0   90.0     5.0
# 1  02-01-2010  21.0  29.6  25.7    95.0  24.0  0.2   6.0   90.0     4.0
# 2  03-01-2010  20.2  26.8  24.5    98.0  63.0  0.0   5.0   90.0     4.0
# 3  04-01-2010  21.0  29.2  25.8    90.0   0.0  0.1   4.0  225.0     3.0
# 4  05-01-2010  21.2  30.0  26.7    90.0   2.0  0.4   NaN    NaN     NaN
#
#   ddd_car  station_id
# 0      E        96001
# 1      E        96001
# 2      E        96001
# 3      SW       96001
# 4     NaN       96001

# %% [markdown]
# Desc
#
# 1.   Tn:	min temperature (°C)
# 2.   Tx:	max temperature (°C)
# 3. Tavg:	avg temperature (°C)
#
# 1.   RH_avg:	avg humidity (%)
# 2.   RR:	rainfall (mm)
#
# 6.   ss:	duration of sunshine (hour)
# 7. ff_x:	max wind speed (m/s)
# 8. ddd_x:	wind direction at maximum speed (°)
# 9. ff_avg:	avg wind speed (m/s)
# 10. ddd_car:	most wind direction (°)
# 11. station_id:	station id which record the data. Detail of the station can be found in station_detail.csv

# %%
df_station = pd.read_csv('/content/indonesia-climate/station_detail.csv')
df_station.head()
# Out:
#    station_id                                       station_name  \
# 0       96001                   Stasiun Meteorologi Maimun Saleh
# 1       96003  Balai Besar Meteorologi Klimatologi  dan Geofi...
# 2       96004  Balai Besar Meteorologi Klimatologi dan Geofis...
# 3       96009                   Stasiun Meteorologi Malikussaleh
# 4       96011           Stasiun Meteorologi Sultan Iskandar Muda
#
#        region_name  latitude  longitude  region_id  province_id
# 0      Kota Sabang   5.87655   95.33785         20            1
# 1      Kab. Badung  -8.73810  115.17860        272           17
# 2    Kota Makassar  -5.14283  119.45227        412           26
# 3  Kab. Aceh Utara   5.22869   96.94749          8            1
# 4  Kab. Aceh Besar   5.52244   95.41700          6            1

# %%
df_province=pd.read_csv('/content/indonesia-climate/province_detail.csv')
df_province.head()
# Out:
#    province_id             province_name
# 0            1  Nanggroe Aceh Darussalam
# 1            2            Sumatera Utara
# 2            3            Sumatera Barat
# 3            4                      Riau
# 4            5                     Jambi

# %% [markdown]
# **merged datasets**

# %%
df_merged_1 = df_station.merge(df_province, on = ["province_id"], how = 'left')
df_merged_1.head()
# Out:
#    station_id                                       station_name  \
# 0       96001                   Stasiun Meteorologi Maimun Saleh
# 1       96003  Balai Besar Meteorologi Klimatologi  dan Geofi...
# 2       96004  Balai Besar Meteorologi Klimatologi dan Geofis...
# 3       96009                   Stasiun Meteorologi Malikussaleh
# 4       96011           Stasiun Meteorologi Sultan Iskandar Muda
#
#        region_name  latitude  longitude  region_id  province_id  \
# 0      Kota Sabang   5.87655   95.33785         20            1
# 1      Kab. Badung  -8.73810  115.17860        272           17
# 2    Kota Makassar  -5.14283  119.45227        412           26
# 3  Kab. Aceh Utara   5.22869   96.94749          8            1
# 4  Kab. Aceh Besar   5.52244   95.41700          6            1
#
#               province_name
# 0  Nanggroe Aceh Darussalam
# 1                      Bali
# 2          Sulawesi Selatan
# 3  Nanggroe Aceh Darussalam
# 4  Nanggroe Aceh Darussalam

# %%
df_merged = df.merge(df_merged_1, on = ["station_id"], how = 'left')
df_merged.head()
# Out:
#          date    Tn    Tx  Tavg  RH_avg    RR   ss  ff_x  ddd_x  ff_avg  \
# 0  01-01-2010  21.4  30.2  27.1    82.0   9.0  0.5   7.0   90.0     5.0
# 1  02-01-2010  21.0  29.6  25.7    95.0  24.0  0.2   6.0   90.0     4.0
# 2  03-01-2010  20.2  26.8  24.5    98.0  63.0  0.0   5.0   90.0     4.0
# 3  04-01-2010  21.0  29.2  25.8    90.0   0.0  0.1   4.0  225.0     3.0
# 4  05-01-2010  21.2  30.0  26.7    90.0   2.0  0.4   NaN    NaN     NaN
#
#   ddd_car  station_id                      station_name  region_name  \
# 0      E        96001  Stasiun Meteorologi Maimun Saleh  Kota Sabang
# 1      E        96001  Stasiun Meteorologi Maimun Saleh  Kota Sabang
# 2      E        96001  Stasiun Meteorologi Maimun Saleh  Kota Sabang
# 3      SW       96001  Stasiun Meteorologi Maimun Saleh  Kota Sabang
# 4     NaN       96001  Stasiun Meteorologi Maimun Saleh  Kota Sabang
#
#    latitude  longitude  region_id  province_id             province_name
# 0   5.87655   95.33785         20            1  Nanggroe Aceh Darussalam
# 1   5.87655   95.33785         20            1  Nanggroe Aceh Darussalam
# 2   5.87655   95.33785         20            1  Nanggroe Aceh Darussalam
# 3   5.87655   95.33785         20            1  Nanggroe Aceh Darussalam
# 4   5.87655   95.33785         20            1  Nanggroe Aceh Darussalam

# %%
df_merged.nunique()
# Out:
# date             4018
# Tn                218
# Tx                254
# Tavg              202
# RH_avg             81
# RR               1734
# ss                188
# ff_x               70
# ddd_x             373
# ff_avg             57
# ddd_car             9
# station_id        173
# station_name      173
# region_name       147
# latitude          169
# longitude         171
# region_id         147
# province_id        34
# province_name      34
# dtype: int64

# %% [markdown]
# **choose only several features that will be used in data dashboard**

# %%
df_new = df_merged[['date', 'Tn', 'Tx', 'Tavg', 'RH_avg', 'RR', 'ss', 'station_id', 'station_name', 'latitude', 'longitude', 'region_name', 'region_id', 'province_id', 'province_name']]
df_new.head()
# Out:
#          date    Tn    Tx  Tavg  RH_avg    RR   ss  station_id  \
# 0  01-01-2010  21.4  30.2  27.1    82.0   9.0  0.5       96001
# 1  02-01-2010  21.0  29.6  25.7    95.0  24.0  0.2       96001
# 2  03-01-2010  20.2  26.8  24.5    98.0  63.0  0.0       96001
# 3  04-01-2010  21.0  29.2  25.8    90.0   0.0  0.1       96001
# 4  05-01-2010  21.2  30.0  26.7    90.0   2.0  0.4       96001
#
#                        station_name  latitude  longitude  region_name  \
# 0  Stasiun Meteorologi Maimun Saleh   5.87655   95.33785  Kota Sabang
# 1  Stasiun Meteorologi Maimun Saleh   5.87655   95.33785  Kota Sabang
# 2  Stasiun Meteorologi Maimun Saleh   5.87655   95.33785  Kota Sabang
# 3  Stasiun Meteorologi Maimun Saleh   5.87655   95.33785  Kota Sabang
# 4  Stasiun Meteorologi Maimun Saleh   5.87655   95.33785  Kota Sabang
#
#    region_id  province_id             province_name
# 0         20            1  Nanggroe Aceh Darussalam
# 1         20            1  Nanggroe Aceh Darussalam
# 2         20            1  Nanggroe Aceh Darussalam
# 3         20            1  Nanggroe Aceh Darussalam
# 4         20            1  Nanggroe Aceh Darussalam

# %% [markdown]
# **drop outliers**

# %%
df_new.Tn.nlargest(10), df_new.Tn.nsmallest(15)
# Out:
# (271670    246.0
#  47088      92.0
#  15211      40.0
#  15304      40.0
#  522190     40.0
#  236268     37.0
#  236291     37.0
#  236266     36.0
#  236270     36.0
#  236282     36.0
#  Name: Tn, dtype: float64,
#  59776     0.0
#  59777     0.0
#  59779     0.0
#  59781     0.0
#  59784     0.0
#  59785     0.0
#  59786     0.0
#  59787     0.0
#  59788     0.0
#  59789     0.0
#  59790     0.0
#  156205    0.0
#  156206    0.0
#  156207    0.0
#  156208    0.0
#  Name: Tn, dtype: float64)

# %%
df_new.drop(df['Tn'].nlargest(2).index, axis=0, inplace=True)
# Out:
# <ipython-input-50-179e7f8edb92>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new.drop(df['Tn'].nlargest(2).index, axis=0, inplace=True)

# %%
df_new.Tx.nlargest(10), df_new.Tn.nsmallest(10)
# Out:
# (272118    334.0
#  300708    330.0
#  272101    321.8
#  581835    294.0
#  581866     98.3
#  573873     92.0
#  502880     85.0
#  345269     83.0
#  528612     83.0
#  98321      71.6
#  Name: Tx, dtype: float64,
#  59776    0.0
#  59777    0.0
#  59779    0.0
#  59781    0.0
#  59784    0.0
#  59785    0.0
#  59786    0.0
#  59787    0.0
#  59788    0.0
#  59789    0.0
#  Name: Tn, dtype: float64)

# %%
df_new.drop(df['Tx'].nlargest(4).index, axis=0, inplace=True)
# Out:
# <ipython-input-52-2da2c89b8fd3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new.drop(df['Tx'].nlargest(4).index, axis=0, inplace=True)

# %%
df_new.Tavg.nlargest(10), df_new.Tn.nsmallest(10)
# Out:
# (271470    141.6
#  127865    141.5
#  202933     35.2
#  39721      34.5
#  253186     34.3
#  266898     34.3
#  406041     34.3
#  78201      34.1
#  148050     33.9
#  102688     33.6
#  Name: Tavg, dtype: float64,
#  59776    0.0
#  59777    0.0
#  59779    0.0
#  59781    0.0
#  59784    0.0
#  59785    0.0
#  59786    0.0
#  59787    0.0
#  59788    0.0
#  59789    0.0
#  Name: Tn, dtype: float64)

# %%
df_new.drop(df['Tavg'].nlargest(2).index, axis=0, inplace=True)
# Out:
# <ipython-input-54-78650ef67e44>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new.drop(df['Tavg'].nlargest(2).index, axis=0, inplace=True)

# %%
df_new.RH_avg.nlargest(10), df_new.Tn.nsmallest(10)
# Out:
# (253370    7520.0
#  362399    5045.0
#  93163     2555.0
#  248635     488.0
#  248167     432.0
#  141245     259.0
#  127903     235.0
#  14805      100.0
#  18102      100.0
#  18457      100.0
#  Name: RH_avg, dtype: float64,
#  59776    0.0
#  59777    0.0
#  59779    0.0
#  59781    0.0
#  59784    0.0
#  59785    0.0
#  59786    0.0
#  59787    0.0
#  59788    0.0
#  59789    0.0
#  Name: Tn, dtype: float64)

# %%
df_new.drop(df['RH_avg'].nlargest(3).index, axis=0, inplace=True)
# Out:
# <ipython-input-59-d2c481385ebd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new.drop(df['RH_avg'].nlargest(3).index, axis=0, inplace=True)

# %%
df_new.RR.nlargest(10), df_new.Tn.nsmallest(15)
# Out:
# (357063    1965.5
#  357062    1460.5
#  357045    1442.0
#  357060    1142.0
#  83847      470.0
#  273653     397.4
#  85021      378.0
#  84935      370.3
#  318492     364.1
#  553107     360.0
#  Name: RR, dtype: float64,
#  59776     0.0
#  59777     0.0
#  59779     0.0
#  59781     0.0
#  59784     0.0
#  59785     0.0
#  59786     0.0
#  59787     0.0
#  59788     0.0
#  59789     0.0
#  59790     0.0
#  156205    0.0
#  156206    0.0
#  156207    0.0
#  156208    0.0
#  Name: Tn, dtype: float64)

# %%
df_new.drop(df['RR'].nlargest(5).index, axis=0, inplace=True)
# Out:
# <ipython-input-61-326581f0bd16>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new.drop(df['RR'].nlargest(5).index, axis=0, inplace=True)

# %%
df_new.ss.nlargest(10), df_new.Tn.nsmallest(15)
# Out:
# (347544    705.0
#  588501    303.0
#  300295    103.0
#  299764     99.0
#  299712     95.0
#  587646     95.0
#  299612     91.0
#  299731     91.0
#  309885     88.0
#  299614     79.0
#  Name: ss, dtype: float64,
#  59776     0.0
#  59777     0.0
#  59779     0.0
#  59781     0.0
#  59784     0.0
#  59785     0.0
#  59786     0.0
#  59787     0.0
#  59788     0.0
#  59789     0.0
#  59790     0.0
#  156205    0.0
#  156206    0.0
#  156207    0.0
#  156208    0.0
#  Name: Tn, dtype: float64)

# %%
df_new.drop(df['ss'].nlargest(3).index, axis=0, inplace=True)
# Out:
# <ipython-input-63-4250cffc0c6b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new.drop(df['ss'].nlargest(3).index, axis=0, inplace=True)

# %% [markdown]
# **check null values**

# %%
df_new.isna().sum()
# Out:
# date                  0
# Tn                23382
# Tx                37736
# Tavg              45104
# RH_avg            48181
# RR               125376
# ss                43716
# station_id            0
# station_name          0
# latitude              0
# longitude             0
# region_name           0
# region_id             0
# province_id           0
# province_name         0
# dtype: int64

# %% [markdown]
# fill null values -> here i am using backward fill since the data is sorted based on the station_id group, it is likely that the values in the next row still belong to data with the same station_id

# %%
df_new_ver = df_new.bfill()
df_new_ver.isna().sum()
# Out:
# date             0
# Tn               0
# Tx               0
# Tavg             0
# RH_avg           0
# RR               0
# ss               0
# station_id       0
# station_name     0
# latitude         0
# longitude        0
# region_name      0
# region_id        0
# province_id      0
# province_name    0
# dtype: int64

# %% [markdown]
# formatting date

# %%
df_new_ver.date = pd.to_datetime(df_new_ver.date, format = '%d-%m-%Y')
df_new_ver.head()
# Out:
#         date    Tn    Tx  Tavg  RH_avg    RR   ss  station_id  \
# 0 2010-01-01  21.4  30.2  27.1    82.0   9.0  0.5       96001
# 1 2010-01-02  21.0  29.6  25.7    95.0  24.0  0.2       96001
# 2 2010-01-03  20.2  26.8  24.5    98.0  63.0  0.0       96001
# 3 2010-01-04  21.0  29.2  25.8    90.0   0.0  0.1       96001
# 4 2010-01-05  21.2  30.0  26.7    90.0   2.0  0.4       96001
#
#                        station_name  latitude  longitude  region_name  \
# 0  Stasiun Meteorologi Maimun Saleh   5.87655   95.33785  Kota Sabang
# 1  Stasiun Meteorologi Maimun Saleh   5.87655   95.33785  Kota Sabang
# 2  Stasiun Meteorologi Maimun Saleh   5.87655   95.33785  Kota Sabang
# 3  Stasiun Meteorologi Maimun Saleh   5.87655   95.33785  Kota Sabang
# 4  Stasiun Meteorologi Maimun Saleh   5.87655   95.33785  Kota Sabang
#
#    region_id  province_id             province_name
# 0         20            1  Nanggroe Aceh Darussalam
# 1         20            1  Nanggroe Aceh Darussalam
# 2         20            1  Nanggroe Aceh Darussalam
# 3         20            1  Nanggroe Aceh Darussalam
# 4         20            1  Nanggroe Aceh Darussalam

# %%
df_new_ver.describe().T
# Out:
#                 count          mean         std          min       25%  \
# Tn           589246.0     23.306878    2.281663      0.00000     23.00
# Tx           589246.0     31.508220    2.301294      0.00000     30.50
# Tavg         589246.0     26.844507    1.950886      0.00000     26.20
# RH_avg       589246.0     82.452556    6.778468     24.00000     78.00
# RR           589246.0      8.653416   17.126833     -1.00000      0.00
# ss           589246.0      5.079478    3.085349      0.00000      2.60
# station_id   589246.0  96832.949369  542.421028  96001.00000  96293.00
# latitude     589246.0     -2.997268    4.071480    -10.76662     -6.70
# longitude    589246.0    114.539282   11.337796     95.33785    106.25
# region_id    589246.0    272.116569  143.948516      1.00000    149.00
# province_id  589246.0     17.657233    9.820728      1.00000     10.00
#
#                      50%        75%          max
# Tn              24.00000     25.000     40.00000
# Tx              31.80000     33.000     98.30000
# Tavg            27.20000     28.000     35.20000
# RH_avg          83.00000     87.000    488.00000
# RR               1.20000      9.400    397.40000
# ss               5.30000      7.600     99.00000
# station_id   96797.00000  97240.000  97980.00000
# latitude        -3.04524     -0.030      5.87655
# longitude      112.78330    122.449    140.72000
# region_id      287.00000    399.000    507.00000
# province_id     18.00000     26.000     34.00000

# %%
df_new_ver.to_csv('climate-change-clean.csv', index=False)
